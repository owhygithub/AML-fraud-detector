# %% [markdown]
# # GRAPH NEURAL NETWORK (GNN) EMBEDDINGS

# %%
import pickle
import torch
import time
import random
import datetime
import numpy as np
import pandas as pd
import networkx as nx
import torch.nn as nn
import matplotlib.pyplot as plt
import torch.optim as optim
from functions import *
from pandas import Timestamp
from torch_geometric.data import Data
from torch_geometric.nn import GCNConv
from torch_geometric.loader import DataLoader
from torch_geometric.utils import negative_sampling, train_test_split_edges

# %% [markdown]
# ![Screenshot 2024-05-22 at 18.37.26.png](<attachment:Screenshot 2024-05-22 at 18.37.26.png>)

# %% [markdown]
# # LOADING GRAPH from Jupyter Notebook
# \(only use if not using Class Preprocessor)

# %%
# with open("graph_data.pickle", "rb") as f:
#     loaded_data = pickle.load(f)
# # fraudulent transaction:
# fraudulent_transaction = (labels==1).nonzero().squeeze()
# print(fraudulent_transaction)
# print(input_data)

# %% [markdown]
# # PROCESS DATA directly

# %%
filename = '/Users/owhy/Documents/Datasets/HI-Small_Trans_3.csv'
# Create an instance of the AMLDataPreprocessing class
data_preprocessor = AMLDataPreprocessing(filename)
# Process the data
input_data, graph_full, x, y, labels, links, edges_amount, node_features, edges_features = data_preprocessor.process_data()
# Visualize
visual = data_preprocessor.visualize_graph(links, edges_amount)
# Out:
# Data Head - <bound method NDFrame.head of              Timestamp  From Bank    Account  To Bank  Account.1  \
# 0     2022/09/01 00:20         10  8000EBD30       10  8000EBD30
# 1     2022/09/01 00:20       3208  8000F4580        1  8000F5340
# 2     2022/09/01 00:00       3209  8000F4670     3209  8000F4670
# 3     2022/09/01 00:02         12  8000F5030       12  8000F5030
# 4     2022/09/01 00:06         10  8000F5200       10  8000F5200
# ...                ...        ...        ...      ...        ...
# 4994  2022/09/01 00:15      11318  80087D580    11318  80087D580
# 4995  2022/09/01 00:02       1674  80087D1B0     1674  80087D1B0
# 4996  2022/09/01 00:19        220  80087EA60      220  80087EA60
# 4997  2022/09/01 00:19       2843  8008789D0     2843  8008789D0
# 4998  2022/09/01 00:29       1674  80087AC10     1674  80087AC10
#
#       Amount Received Receiving Currency  Amount Paid Payment Currency  \
# 0             3697.34          US Dollar      3697.34        US Dollar
# 1                0.01          US Dollar         0.01        US Dollar
# 2            14675.57          US Dollar     14675.57        US Dollar
# 3             2806.97          US Dollar      2806.97        US Dollar
# 4            36682.97          US Dollar     36682.97        US Dollar
# ...               ...                ...          ...              ...
# 4994            15.73          US Dollar        15.73        US Dollar
# 4995            12.19          US Dollar        12.19        US Dollar
# 4996          2075.73          US Dollar      2075.73        US Dollar
# 4997           604.51          US Dollar       604.51        US Dollar
# 4998            13.93          US Dollar        13.93        US Dollar
#
#      Payment Format  Is Laundering
# 0      Reinvestment              0
# 1            Cheque              0
# 2      Reinvestment              0
# 3      Reinvestment              0
# 4      Reinvestment              0
# ...             ...            ...
# 4994   Reinvestment              0
# 4995   Reinvestment              0
# 4996   Reinvestment              0
# 4997   Reinvestment              0
# 4998   Reinvestment              0
#
# [4999 rows x 11 columns]>
# Shape of DataFrame - (4999, 11)
# Null elements?
# Timestamp             0
# From Bank             0
# Account               0
# To Bank               0
# Account.1             0
# Amount Received       0
# Receiving Currency    0
# Amount Paid           0
# Payment Currency      0
# Payment Format        0
# Is Laundering         0
# dtype: int64
# Fraudulent or Not? - Y labels
# Number of fraudulent transactions - 1
# Number of non-fraudulent transactions - 4998
# Laundering Accounts - ['100428660']
# Are Amount Paid entirely equal to Amount Received?
#  - False
# Are Currency Received entirely equal to Currency Paid?
#  - False
# ['Bitcoin', 'Euro', 'US Dollar']
# ['Bitcoin', 'Euro', 'US Dollar']
# ['ACH', 'Bitcoin', 'Cash', 'Cheque', 'Credit Card', 'Reinvestment', 'Wire']
# Number of unique accounts: 4188
# Longest String is  - 110011100001101010 w/ length - 18
# [('8000EBD30', '8000EBD30', {'label': '3697.34'}), ('8000F4580', '8000F5340', {'label': '0.01'}), ('8000F4670', '8000F4670', {'label': '14675.57'}), ('8000F5030', '8000F5030', {'label': '2806.97'}), ('8000F5200', '8000F5200', {'label': '36682.97'}), ('8000F5AD0', '8000F5AD0', {'label': '6162.44'}), ('8000EBAC0', '8000EBAC0', {'label': '14.26'}), ('8000EC1E0', '8000EC1E0', {'label': '11.86'}), ('8000EC280', '8017BF800', {'label': '7.66'}), ('8000EDEC0', '80AEF5310', {'label': '383.71'}), ('8000F4510', '8011305D0', {'label': '9.82'}), ('8000F47F0', '8000F47F0', {'label': '9.38'}), ('8000F4FE0', '812ED62E0', {'label': '4.01'}), ('80012FD90', '812ED6380', {'label': '106.7'}), ('80012FE00', '805B34210', {'label': '0.54'}), ('80012FE50', '80012FE50', {'label': '3944232.29'}), ('80012FEA0', '80012FEA0', {'label': '10020.68'}), ('8005DFEB0', '8005DFEB0', {'label': '897.37'}), ('8005E18F0', '8005E18F0', {'label': '9.89'}), ('8005E24C0', '8005E24C0', {'label': '52.75'}), ('8005F2D30', '8005F2D30', {'label': '8163.85'}), ('800131480', '800131480', {'label': '5.74'}), ('800131B10', '8131A9A80', {'label': '46.86'}), ('8005F0B50', '810B0FB40', {'label': '86.3'}), ('8005FB700', '813600910', {'label': '3.16'}), ('8005FD390', '8005FD390', {'label': '780457.62'}), ('8005FD390', '8006A3890', {'label': '38386097.0'}), ('8005FD430', '8005FD430', {'label': '748.62'}), ('8005FD430', '800058100', {'label': '159271.0'}), ('800A5F020', '8006A3840', {'label': '1210984.0'}), ('800A5F020', '80068A1B0', {'label': '68.69'}), ('8006A3840', '80C132DC0', {'label': '3.62'}), ('8006A3890', '80A3C7390', {'label': '192.83'}), ('8006AF500', '8006AF500', {'label': '956.43'}), ('8006AF550', '8006AF550', {'label': '43.44'}), ('800AC8E30', '800AC8E30', {'label': '4295104.54'}), ('800AC8E30', '801008520', {'label': '5069.19'}), ('800AC8E30', '80005D5C0', {'label': '29382.0'}), ('800AC9010', '800AC9010', {'label': '3203.2'}), ('800AC9010', '801008340', {'label': '152631.0'}), ('800ACA9C0', '800ACA9C0', {'label': '192154.42'}), ('801008340', '8082250C0', {'label': '16.9'}), ('801008520', '80974B620', {'label': '17.57'}), ('800AC8E80', '800AC8E80', {'label': '7.64'}), ('800AC9400', '814233CC0', {'label': '16.03'}), ('814233CC0', '800AC9E20', {'label': '146.97'}), ('800AC9DD0', '8121CF4B0', {'label': '25.34'}), ('801008480', '8065002B0', {'label': '87.71'}), ('8010098B0', '8010098B0', {'label': '19605.49'}), ('801009860', '80100A2C0', {'label': '424245.0'}), ('801009860', '80100D180', {'label': '2995.0'}), ('801009860', '80100DB80', {'label': '527190.0'}), ('801009860', '801009860', {'label': '17.29'}), ('80100A2C0', '80805AE20', {'label': '6.88'}), ('80100D180', '803177AF0', {'label': '406.38'}), ('80100DB80', '80A059840', {'label': '42.18'}), ('8012261B0', '8012261B0', {'label': '15018.93'}), ('80100DB30', '80805A830', {'label': '9.57'}), ('8012275D0', '8012275D0', {'label': '4.62'}), ('8012275D0', '801227620', {'label': '8468.0'}), ('8012275D0', '80141ED50', {'label': '13818883.0'}), ('8012275D0', '8004169F0', {'label': '9814809.87'}), ('8012275D0', '800416A40', {'label': '2782.0'}), ('801227620', '802F2FD40', {'label': '44.54'}), ('80141ED50', '805DEB4F0', {'label': '77.15'}), ('8004169F0', '80A0DDC70', {'label': '6.28'}), ('800416A40', '8051B9F40', {'label': '130.1'}), ('80152BF60', '80152BF60', {'label': '11.77'}), ('80152E780', '81173FE50', {'label': '5.87'}), ('8016B82E0', '8016B82E0', {'label': '756221.89'}), ('8016BA970', '8016BA970', {'label': '24068.17'}), ('8016BC320', '8016BBF40', {'label': '106953.0'}), ('8016BC320', '8016BC320', {'label': '1282.15'}), ('8016BBF40', '80DF7DCE0', {'label': '149.35'}), ('8016BA470', '8016BBF90', {'label': '25397.0'}), ('8016BBF90', '8017A8630', {'label': '97.86'}), ('8016BC820', '8016BC820', {'label': '489.99'}), ('8016BBEA0', '8016BBEA0', {'label': '11.68'}), ('8016BC370', '8016BC370', {'label': '17.38'}), ('8016CAB70', '80E2754A0', {'label': '51.44'}), ('8018754D0', '80D120A40', {'label': '46.3'}), ('801342560', '801342560',  ...
# [('8000EBD30', '8000EBD30', {'label': '3697.34'}), ('8000F4580', '8000F5340', {'label': '0.01'}), ('8000F4670', '8000F4670', {'label': '14675.57'}), ('8000F5030', '8000F5030', {'label': '2806.97'}), ('8000F5200', '8000F5200', {'label': '36682.97'}), ('8000F5AD0', '8000F5AD0', {'label': '6162.44'}), ('8000EBAC0', '8000EBAC0', {'label': '14.26'}), ('8000EC1E0', '8000EC1E0', {'label': '11.86'}), ('8000EC280', '8017BF800', {'label': '7.66'}), ('8000EDEC0', '80AEF5310', {'label': '383.71'}), ('8000F4510', '8011305D0', {'label': '9.82'}), ('8000F47F0', '8000F47F0', {'label': '9.38'}), ('8000F4FE0', '812ED62E0', {'label': '4.01'}), ('80012FD90', '812ED6380', {'label': '106.7'}), ('80012FE00', '805B34210', {'label': '0.54'}), ('80012FE50', '80012FE50', {'label': '3944232.29'}), ('80012FEA0', '80012FEA0', {'label': '10020.68'}), ('8005DFEB0', '8005DFEB0', {'label': '897.37'}), ('8005E18F0', '8005E18F0', {'label': '9.89'}), ('8005E24C0', '8005E24C0', {'label': '52.75'}), ('8005F2D30', '8005F2D30', {'label': '8163.85'}), ('800131480', '800131480', {'label': '5.74'}), ('800131B10', '8131A9A80', {'label': '46.86'}), ('8005F0B50', '810B0FB40', {'label': '86.3'}), ('8005FB700', '813600910', {'label': '3.16'}), ('8005FD390', '8005FD390', {'label': '780457.62'}), ('8005FD390', '8006A3890', {'label': '38386097.0'}), ('8005FD430', '8005FD430', {'label': '748.62'}), ('8005FD430', '800058100', {'label': '159271.0'}), ('800A5F020', '8006A3840', {'label': '1210984.0'}), ('8006A3840', '80C132DC0', {'label': '3.62'}), ('8006A3890', '80A3C7390', {'label': '192.83'}), ('8006AF500', '8006AF500', {'label': '956.43'}), ('8006AF550', '8006AF550', {'label': '43.44'}), ('800AC8E30', '800AC8E30', {'label': '4295104.54'}), ('800AC8E30', '801008520', {'label': '5069.19'}), ('800AC8E30', '80005D5C0', {'label': '29382.0'}), ('800AC9010', '800AC9010', {'label': '3203.2'}), ('800AC9010', '801008340', {'label': '152631.0'}), ('800ACA9C0', '800ACA9C0', {'label': '192154.42'}), ('801008340', '8082250C0', {'label': '16.9'}), ('801008520', '80974B620', {'label': '17.57'}), ('800AC8E80', '800AC8E80', {'label': '7.64'}), ('800AC9400', '814233CC0', {'label': '16.03'}), ('814233CC0', '800AC9E20', {'label': '146.97'}), ('800AC9DD0', '8121CF4B0', {'label': '25.34'}), ('801008480', '8065002B0', {'label': '87.71'}), ('8010098B0', '8010098B0', {'label': '19605.49'}), ('801009860', '80100A2C0', {'label': '424245.0'}), ('801009860', '80100D180', {'label': '2995.0'}), ('801009860', '80100DB80', {'label': '527190.0'}), ('801009860', '801009860', {'label': '17.29'}), ('80100A2C0', '80805AE20', {'label': '6.88'}), ('80100D180', '803177AF0', {'label': '406.38'}), ('80100DB80', '80A059840', {'label': '42.18'}), ('8012261B0', '8012261B0', {'label': '15018.93'}), ('80100DB30', '80805A830', {'label': '9.57'}), ('8012275D0', '8012275D0', {'label': '4.62'}), ('8012275D0', '801227620', {'label': '8468.0'}), ('8012275D0', '80141ED50', {'label': '13818883.0'}), ('8012275D0', '8004169F0', {'label': '9814809.87'}), ('8012275D0', '800416A40', {'label': '2782.0'}), ('801227620', '802F2FD40', {'label': '44.54'}), ('80141ED50', '805DEB4F0', {'label': '77.15'}), ('8004169F0', '80A0DDC70', {'label': '6.28'}), ('800416A40', '8051B9F40', {'label': '130.1'}), ('80152BF60', '80152BF60', {'label': '11.77'}), ('80152E780', '81173FE50', {'label': '5.87'}), ('8016B82E0', '8016B82E0', {'label': '756221.89'}), ('8016BA970', '8016BA970', {'label': '24068.17'}), ('8016BC320', '8016BBF40', {'label': '106953.0'}), ('8016BC320', '8016BC320', {'label': '1282.15'}), ('8016BBF40', '80DF7DCE0', {'label': '149.35'}), ('8016BA470', '8016BBF90', {'label': '25397.0'}), ('8016BBF90', '8017A8630', {'label': '97.86'}), ('8016BC820', '8016BC820', {'label': '489.99'}), ('8016BBEA0', '8016BBEA0', {'label': '11.68'}), ('8016BC370', '8016BC370', {'label': '17.38'}), ('8016CAB70', '80E2754A0', {'label': '51.44'}), ('8018754D0', '80D120A40', {'label': '46.3'}), ('801342560', '801342560', {'label': '6.11'}), ('8018859B0', '8018859B0', { ...

# %% [markdown]
# # GRAPH NEURAL NETWORKS

# %%
import torch
import torch.nn.functional as F
from torch_geometric.nn import GCNConv, NNConv
from torch_geometric.data import Data
from torch_geometric.utils import add_self_loops, degree

# %%
class GCN01(nn.Module):
    def __init__(self, in_channels, hidden_channels, out_channels):
        super(GCN01, self).__init__()
        self.conv1 = GCNConv(in_channels, hidden_channels)
        self.relu1 = nn.ReLU()
        self.conv2 = GCNConv(hidden_channels, 128)
        self.relu2 = nn.ReLU()
        self.conv3 = GCNConv(128, 256)
        self.relu3 = nn.ReLU()
        self.conv4 = GCNConv(256, 128)
        self.relu4 = nn.ReLU()
        self.conv5 = GCNConv(128, hidden_channels)
        self.relu5 = nn.ReLU()
        self.conv6 = GCNConv(hidden_channels, out_channels)
        self.sigmoid = nn.Sigmoid()

    def forward(self, x, edge_index):
        x = self.conv1(x, edge_index)
        x = torch.relu(x)
        x = self.conv2(x, edge_index)
        return x

# %%
print(input_data.x.size())
print(input_data.y.size())
# Out:
# torch.Size([4188, 31])
# torch.Size([4999])

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# Define hyperparameters
num_epochs = 300
hidden_channels = 128
out_channels = 64
learning_rate = 0.01

# Initialize the model, optimizer, and loss function
# model = LinkPredictor(in_channels=input_data.num_features, hidden_channels=64, out_channels=32, heads=8).to(device)
# optimizer = optim.SGD(params=model.parameters(), lr=learning_rate) # IDEA SGD = Stochastic Gradient Descent
# # criterion = torch.nn.BCELoss()
# criterion = nn.BCEWithLogitsLoss() # IDEA used for binary classification tasks --> SIGMOID + BINARY CROSS-ENTROPY LOSS

# Initialize the model, optimizer, and loss function
model = GCN01(in_channels=node_features.size(1), hidden_channels=hidden_channels, out_channels=out_channels).to(device)
optimizer = optim.Adam(model.parameters(), lr=0.01)
criterion = nn.BCEWithLogitsLoss()

# Define the data loader
loader = DataLoader([input_data], batch_size=1, shuffle=True)

loss_values = []

# Training loop
for epoch in range(num_epochs):
    model.train()
    total_loss = 0
    total_fraudulent_edges = 0  # Initialize total count of fraudulent edges
    fraudulent_indices = []
    for batch in loader:
        batch = batch.to(device)
        optimizer.zero_grad()
        out = model(batch.x, batch.edge_index)
        
        # Reshape the output tensor to match the shape of the target tensor
        out = out.view(-1)  # Flatten the output tensor
        
        # Ensure the dimensions of out and batch.y match
        if out.size(0) != batch.y.size(0):
            batch_size = batch.y.size(0)
            out = out[:batch_size]  # Trim the output tensor to match the batch size
        
        # Compute the binary cross-entropy loss
        loss = criterion(out, batch.y.float())  # Ensure batch.y is float type
        loss.backward()
        optimizer.step()
        total_loss += loss.item()
        
        # Predictions: convert logits to probabilities using sigmoid
        probabilities = torch.sigmoid(out)
        
        # Threshold probabilities to predict fraud (1) or non-fraud (0)
        predicted_labels = (probabilities > 0.5).int()  # Threshold at 0.5
        
        # Count the number of fraudulent edges (predicted as 1)
        fraudulent_edges_in_batch = (predicted_labels == 1).sum().item()
        total_fraudulent_edges += fraudulent_edges_in_batch

        # Find indices of fraudulent transactions
        batch_indices = torch.arange(len(predicted_labels))
        fraudulent_indices_batch = batch_indices[predicted_labels == 1].tolist()
        fraudulent_indices.extend(fraudulent_indices_batch)
    
    loss_values.append(total_loss)  # Store the total loss for this epoch
-06, Fraudulent Edges: 1
# Fraudulent Transaction Indices: [4742]
# Epoch 250, Loss: 2.2466836071544094e-06, Fraudulent Edges: 1
# Fraudulent Transaction Indices: [4742]
# Epoch 251, Loss: 2.2302233446680475e-06, Fraudulent Edges: 1
# Fraudulent Transaction Indices: [4742]
# Epoch 252, Loss: 2.214402911704383e-06, Fraudulent Edges: 1
# Fraudulent Transaction Indices: [4742]
# Epoch 253, Loss: 2.198844413214829e-06, Fraudulent Edges: 1
# Fraudulent Transaction Indices: [4742]
# Epoch 254, Loss: 2.1832638594787568e-06, Fraudulent Edges: 1
# Fraudulent Transaction Indices: [4742]
# Epoch 255, Loss: 2.1676837604900356e-06, Fraudulent Edges: 1
# Fraudulent Transaction Indices: [4742]
# Epoch 256, Loss: 2.1521525468415348e-06, Fraudulent Edges: 1
# Fraudulent Transaction Indices: [4742]
# Epoch 257, Loss: 2.136953753506532e-06, Fraudulent Edges: 1
# Fraudulent Transaction Indices: [4742]
# Epoch 258, Loss: 2.122157638950739e-06, Fraudulent Edges: 1
# Fraudulent Transaction Indices: [4742]
# Epoch 259, Loss: 2.107359932779218e-06, Fraudulent Edges: 1
# Fraudulent Transaction Indices: [4742]
# Epoch 260, Loss: 2.0925624539813725e-06, Fraudulent Edges: 1
# Fraudulent Transaction Indices: [4742]
# Epoch 261, Loss: 2.0781442344741663e-06, Fraudulent Edges: 1
# Fraudulent Transaction Indices: [4742]
# Epoch 262, Loss: 2.063915871985955e-06, Fraudulent Edges: 1
# Fraudulent Transaction Indices: [4742]
# Epoch 263, Loss: 2.0497607238212368e-06, Fraudulent Edges: 1
# Fraudulent Transaction Indices: [4742]
# Epoch 264, Loss: 2.0356058030301938e-06, Fraudulent Edges: 1
# Fraudulent Transaction Indices: [4742]
# Epoch 265, Loss: 2.021523414441617e-06, Fraudulent Edges: 1
# Fraudulent Transaction Indices: [4742]
# Epoch 266, Loss: 2.007795274039381e-06, Fraudulent Edges: 1
# Fraudulent Transaction Indices: [4742]
# Epoch 267, Loss: 1.9941617210861295e-06, Fraudulent Edges: 1
# Fraudulent Transaction Indices: [4742]
# Epoch 268, Loss: 1.9809554032690357e-06, Fraudulent Edges: 1
# Fraudulent Transaction Indices: [4742]
# Epoch 269, Loss: 1.967631078514387e-06, Fraudulent Edges: 1
# Fraudulent Transaction Indices: [4742]
# Epoch 270, Loss: 1.9544258975656703e-06, Fraudulent Edges: 1
# Fraudulent Transaction Indices: [4742]
# Epoch 271, Loss: 1.9412452729739016e-06, Fraudulent Edges: 1
# Fraudulent Transaction Indices: [4742]
# Epoch 272, Loss: 1.9286112546978984e-06, Fraudulent Edges: 1
# Fraudulent Transaction Indices: [4742]
# Epoch 273, Loss: 1.916072505991906e-06, Fraudulent Edges: 1
# Fraudulent Transaction Indices: [4742]
# Epoch 274, Loss: 1.9033889202546561e-06, Fraudulent Edges: 1
# Fraudulent Transaction Indices: [4742]
# Epoch 275, Loss: 1.8906583818534273e-06, Fraudulent Edges: 1
# Fraudulent Transaction Indices: [4742]
# Epoch 276, Loss: 1.8781644257614971e-06, Fraudulent Edges: 1
# Fraudulent Transaction Indices: [4742]
# Epoch 277, Loss: 1.8661226022231858e-06, Fraudulent Edges: 1
# Fraudulent Transaction Indices: [4742]
# Epoch 278, Loss: 1.853938897511398e-06, Fraudulent Edges: 1
# Fraudulent Transaction Indices: [4742]
# Epoch 279, Loss: 1.8417081264487933e-06, Fraudulent Edges: 1
# Fraudulent Transaction Indices: [4742]
# Epoch 280, Loss: 1.829858661039907e-06, Fraudulent Edges: 1
# Fraudulent Transaction Indices: [4742]
# Epoch 281, Loss: 1.8180556935476488e-06, Fraudulent Edges: 1
# Fraudulent Transaction Indices: [4742]
# Epoch 282, Loss: 1.8062519302475266e-06, Fraudulent Edges: 1
# Fraudulent Transaction Indices: [4742]
# Epoch 283, Loss: 1.794946570043976e-06, Fraudulent Edges: 1
# Fraudulent Transaction Indices: [4742]
# Epoch 284, Loss: 1.783594370863284e-06, Fraudulent Edges: 1
# Fraudulent Transaction Indices: [4742]
# Epoch 285, Loss: 1.772123709997686e-06, Fraudulent Edges: 1
# Fraudulent Transaction Indices: [4742]
# Epoch 286, Loss: 1.7609152109798742e-06, Fraudulent Edges: 1
# Fraudulent Transaction Indices: [4742]
# Epoch 287, Loss: 1.750087903928943e-06, Fraudulent Edges: 1
# Fraudulent Transaction Indices: [4742]
# Epoch 288, Loss: 1.7390931361660478e-06, Fraudulent Edges: 1
# Fraudulent Transaction Indices: [4742]
# Epoch 289, Loss: 1.7281216742048855e-06, Fraudulent Edges: 1
# Fraudulent Transaction Indices: [4742]
# Epoch 290, Loss: 1.7171971649077022e-06, Fraudulent Edges: 1
# Fraudulent Transaction Indices: [4742]
# Epoch 291, Loss: 1.7064854773707339e-06, Fraudulent Edges: 1
# Fraudulent Transaction Indices: [4742]
# Epoch 292, Loss: 1.6960124185061431e-06, Fraudulent Edges: 1
# Fraudulent Transaction Indices: [4742]
# Epoch 293, Loss: 1.6856107549756416e-06, Fraudulent Edges: 1
# Fraudulent Transaction Indices: [4742]
# Epoch 294, Loss: 1.675162593528512e-06, Fraudulent Edges: 1
# Fraudulent Transaction Indices: [4742]
# Epoch 295, Loss: 1.664691694713838e-06, Fraudulent Edges: 1
# Fraudulent Transaction Indices: [4742]
# Epoch 296, Loss: 1.6546958931940026e-06, Fraudulent Edges: 1
# Fraudulent Transaction Indices: [4742]
# Epoch 297, Loss: 1.6447710322609055e-06, Fraudulent Edges: 1
# Fraudulent Transaction Indices: [4742]
# Epoch 298, Loss: 1.6349644056390389e-06, Fraudulent Edges: 1
# Fraudulent Transaction Indices: [4742]
# Epoch 299, Loss: 1.6247527128143702e-06, Fraudulent Edges: 1
# Fraudulent Transaction Indices: [4742]
# Epoch 300, Loss: 1.6146361758728744e-06, Fraudulent Edges: 1
# Fraudulent Transaction Indices: [4742]

# %%
# Plot the loss values
plt.figure(figsize=(10, 5))
plt.plot(range(1, num_epochs + 1), loss_values, label='Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training Loss Over Epochs')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# # TESTING

# %%
filename = '/Users/owhy/Documents/Datasets/HI-Small_Trans_3_testing.csv'
# Create an instance of the AMLDataPreprocessing class
data_preprocessor = AMLDataPreprocessing(filename)
# Process the data
new_input_data, graph_full, x, y, labels, links, edges_amount = data_preprocessor.process_data()
# Visualize
visual = data_preprocessor.visualize_graph(links, edges_amount)

# %%
# Assuming model is already trained and you have new data for prediction
# For demonstration purposes, let's assume you have a new graph represented as `new_input_data`

# Set model to evaluation mode
model.eval()

# Make predictions on the new data
with torch.no_grad():
    new_input_data = new_input_data.to(device)
    predicted_logits = model(new_input_data.x, new_input_data.edge_index)
    predicted_probabilities = torch.sigmoid(predicted_logits)

# Convert logits to probabilities using sigmoid
predicted_labels = (predicted_probabilities > 0.5).int()  # Threshold at 0.5

# Visualize the predictions
# For example, you could print out the predicted labels for each edge
for i, edge in enumerate(new_input_data.edge_index.t().tolist()):
    print(f'Edge {edge}: Predicted Probability: {predicted_probabilities[i].item()}, Predicted Label: {predicted_labels[i].item()}')
